# %%
import numpy as np
import pandas as pd
import nltk

# %%
raw = pd.read_excel('NLP_Data.xlsx')

# %%
raw
# Out:
#                           Description of the Grievance  \
# 0    concerns regarding laboratory tests being bill...
# 1                         dassatifaction with provider
# 2                Dissatisafaction with delay in care.
# 3    Dissatisafaction with Dental provider way of c...
# 4    Dissatisfaction for not being informed he had ...
# ..                                                 ...
# 520  Who: The member is requesting appeal  Why: The...
# 521   Why: Member states she was denied covid-19 bo...
# 522                                                NaN
# 523                                                NaN
# 524                                                NaN
#
#             Grievance Category                 Grievance SubCategory
# 0    Billing/Financial Dispute                 Provider Claim Issues
# 1           Quality Of Service  Not Satisfied With Provider Services
# 2      Access And Availability                              Pharmacy
# ...

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Description of the Grievance  522 non-null    object
#  1   Grievance Category            502 non-null    object
#  2   Grievance SubCategory         502 non-null    object
# dtypes: object(3)
# memory usage: 12.4+ KB

# %%
raw.columns
# Out:
# Index(['Description of the Grievance', 'Grievance Category',
#        'Grievance SubCategory'],
#       dtype='object')

# %%
raw.dropna(subset=['Description of the Grievance'], inplace =True)

# %%
raw.tail()
# Out:
#                           Description of the Grievance  \
# 517  Who: member. Why: member got a letter of denia...
# 518  Who: Member  Why: the cost of the member's RX ...
# 519  Who: The mbr  Why: The mbr is dissatisfied bec...
# 520  Who: The member is requesting appeal  Why: The...
# 521   Why: Member states she was denied covid-19 bo...
#
#           Grievance Category Grievance SubCategory
# 517                      NaN                   NaN
# 518          Benefit Package                 Other
# 519          Quality Of Care                   Pcp
# 520          Quality Of Care                 Other
# 521  Access And Availability                 Other

# %%
incomplete = raw[raw['Grievance Category'].isnull()]
complete = raw[raw['Grievance Category'].notnull()]

# %%
complete
# Out:
#                           Description of the Grievance  \
# 0    concerns regarding laboratory tests being bill...
# 1                         dassatifaction with provider
# 2                Dissatisafaction with delay in care.
# 3    Dissatisafaction with Dental provider way of c...
# 4    Dissatisfaction for not being informed he had ...
# ..                                                 ...
# 516  Who: Member is appealing charge for no show of...
# 518  Who: Member  Why: the cost of the member's RX ...
# 519  Who: The mbr  Why: The mbr is dissatisfied bec...
# 520  Who: The member is requesting appeal  Why: The...
# 521   Why: Member states she was denied covid-19 bo...
#
#             Grievance Category                 Grievance SubCategory
# 0    Billing/Financial Dispute                 Provider Claim Issues
# 1           Quality Of Service  Not Satisfied With Provider Services
# 2      Access And Availability                              Pharmacy
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
Tokens = [word_tokenize(word) for word in complete['Description of the Grievance']]

# %%
complete['Description of the Grievance'] = Tokens
# Out:
# C:\Users\KIIT01\AppData\Local\Temp\ipykernel_16040\3846702435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete['Description of the Grievance'] = Tokens

# %%
complete
# Out:
#                           Description of the Grievance  \
# 0    [concerns, regarding, laboratory, tests, being...
# 1                     [dassatifaction, with, provider]
# 2         [Dissatisafaction, with, delay, in, care, .]
# 3    [Dissatisafaction, with, Dental, provider, way...
# 4    [Dissatisfaction, for, not, being, informed, h...
# ..                                                 ...
# 516  [Who, :, Member, is, appealing, charge, for, n...
# 518  [Who, :, Member, Why, :, the, cost, of, the, m...
# 519  [Who, :, The, mbr, Why, :, The, mbr, is, dissa...
# 520  [Who, :, The, member, is, requesting, appeal, ...
# 521  [Why, :, Member, states, she, was, denied, cov...
#
#             Grievance Category                 Grievance SubCategory
# 0    Billing/Financial Dispute                 Provider Claim Issues
# 1           Quality Of Service  Not Satisfied With Provider Services
# 2      Access And Availability                              Pharmacy
# ...

# %%
import re 
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
lemma = WordNetLemmatizer()
def stop_words_removal(data):
    text=[]
    for word in data:
        word=[]
        for i in word:
            res = re.sub(r'[^\w\s]', "", w)
            if res != "":
                word.append(res)
            text.appen(word)
        return text
                
                
                
                
                
#         for i in word:
#             if not i in stopwords.words('english'):
#                 word2.append(i)
#         for i in word2:
#             word3.append(lemma.lemmatize(i))
#         text.append(word3)
#     return text

# %%
clean = stop_words_removal(Tokens)

# %%
clean
# Out:
# []
